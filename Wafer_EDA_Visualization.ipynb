# %% [markdown]
# # 📊 Wafer Fault Detection - EDA & Visualization

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
# Load wafer dataset
df = pd.read_csv("data/wafer.csv")
df.head()
# Out:
#    sensor_1  sensor_2  sensor_3  sensor_4  sensor_5  sensor_6  sensor_7  \
# 0  0.496714 -0.138264  0.647689  1.523030 -0.234153 -0.234137  1.579213
# 1 -0.463418 -0.465730  0.241962 -1.913280 -1.724918 -0.562288 -1.012831
# 2  1.465649 -0.225776  0.067528 -1.424748 -0.544383  0.110923 -1.150994
# 3 -0.601707  1.852278 -0.013497 -1.057711  0.822545 -1.220844  0.208864
# 4  0.738467  0.171368 -0.115648 -0.301104 -1.478522 -0.719844 -0.460639
#
#    sensor_8  sensor_9  sensor_10  label
# 0  0.767435 -0.469474   0.542560     -1
# 1  0.314247 -0.908024  -1.412304      1
# 2  0.375698 -0.600639  -0.291694     -1
# 3 -1.959670 -1.328186   0.196861      1
# 4  1.057122  0.343618  -1.763040     -1

# %% [markdown]
# ## 🔍 Data Overview

# %%
# Basic info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sensor_1   100 non-null    float64
#  1   sensor_2   100 non-null    float64
#  2   sensor_3   100 non-null    float64
#  3   sensor_4   100 non-null    float64
#  4   sensor_5   100 non-null    float64
#  5   sensor_6   100 non-null    float64
#  6   sensor_7   100 non-null    float64
#  7   sensor_8   100 non-null    float64
#  8   sensor_9   100 non-null    float64
#  9   sensor_10  100 non-null    float64
#  10  label      100 non-null    int64
# dtypes: float64(10), int64(1)
# memory usage: 8.7 KB

# %%
# Check missing values
df.isnull().sum()
# Out:
# sensor_1     0
# sensor_2     0
# sensor_3     0
# sensor_4     0
# sensor_5     0
# sensor_6     0
# sensor_7     0
# sensor_8     0
# sensor_9     0
# sensor_10    0
# label        0
# dtype: int64

# %% [markdown]
# ## 📈 Statistical Summary

# %%
df.describe()
# Out:
#          sensor_1    sensor_2    sensor_3    sensor_4    sensor_5    sensor_6  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     0.003618    0.002578   -0.048511    0.108974    0.079499   -0.032549
# std      0.894297    1.047359    1.026363    1.016550    1.042712    0.976823
# min     -1.918771   -2.301921   -3.241267   -2.198806   -2.619745   -2.211135
# 25%     -0.574156   -0.710363   -0.700307   -0.678367   -0.622252   -0.705970
# 50%      0.079078   -0.052911   -0.023125    0.200009   -0.027014   -0.063027
# 75%      0.532233    0.804413    0.636509    0.853640    0.815031    0.637617
# max      2.526932    2.075401    2.560085    2.463242    2.573360    2.632382
#
#          sensor_7    sensor_8    sensor_9   sensor_10       label
# count  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.047772    0.038018    0.031172    0.058295   -0.040000
# std      0.954652    0.904248    0.921830    1.022648    1.004233
# min     -2.696887   -2.423879   -2.650970   -1.987569   -1.000000
# 25%     -0.776155   -0.572616   -0.532816   -0.628305   -1.000000
# 50%      0.013466    0.094496    0.064005   -0.014331   -1.000000
# 75%      0.530416    0.601449    0.552765    0.697232    1.000000
# max      1.886186    2.455300    3.078881    3.852731    1.000000

# %% [markdown]
# ## 🧪 Class Distribution

# %%
sns.countplot(data=df, x='label')
plt.title("Class Distribution (Fault = -1, No Fault = 1)")
plt.show()

# %% [markdown]
# ## 🔬 Feature Distributions

# %%
df.drop('label', axis=1).hist(bins=30, figsize=(15, 10))
plt.suptitle("Sensor Feature Distributions")
plt.show()

# %% [markdown]
# ## 🔗 Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()
